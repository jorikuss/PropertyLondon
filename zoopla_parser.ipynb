# %%
import requests
from bs4 import BeautifulSoup
import csv
import time
import lxml


class ZooplaScraper:
    results = []

    def fetch(self, url):
        print('HTTP GET request to URL: %s' % url, end='')
        res = requests.get(url)
        print(' | Status code: %s' % res.status_code)
        
        return res
    
    def parse(self, html):
        content = BeautifulSoup(html, 'lxml')
        cards = content.findAll('div', {'class': 'listing-results-wrapper'})
    
        for card in cards:
            
            try:
                bedrooms = card.find('span', {"class": "num-icon num-beds"}).text
            except:
                bedrooms = 'NA'

            try:
                bathrooms = card.find('span', {"class": "num-icon num-baths"}).text
            except:
                bathrooms = 'NA'

            try:
                reception = card.find('span', {"class": "num-icon num-reception"}).text
            except:
                reception = 'NA'
            
            try:
                area = card.find('span', {"class": "num-icon num-sqft"}).text
            except:
                area = 'NA'               
                
            self.results.append({
                'link': "https://www.zoopla.co.uk/"+str(card.find('a', {'class': 'listing-results-price text-price'})["href"]),
                'price': card.find('a', {'class': 'listing-results-price'}).text.strip().split(' ')[0].strip(),
                'bedrooms': bedrooms,
                'bathrooms': bathrooms,
                'receptions': reception,
                'area': area,
                'address': card.find('a', {'class': 'listing-results-address'}).text,
                'date': card.find('p', {'class': 'listing-results-marketed'}).text.split('Listed on')[1].split('by')[0].strip(),
                'description': card.find('p').text.strip(),
                'title': card.find('a', {'style': 'text-decoration:underline;'}).text,
                'image': card.find('a', {'class': 'photo-hover'}).find('img')['data-src']
            })
        
    
    def to_csv(self):
        with open('zoopla.csv', 'w',newline='') as csv_file:
            writer = csv.DictWriter(csv_file, fieldnames=self.results[0].keys())
            writer.writeheader()
            for row in self.results:
                writer.writerow(row)
            print('Stored results to "zoopla.csv"')
    
    def run(self):
        for page in range(100):
            url = 'https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn='
            url += str(page+1)
            res = self.fetch(url)
            self.parse(res.text)
            time.sleep(2)

        self.to_csv()
        

if __name__ == '__main__':
    scraperZoop = ZooplaScraper()
    scraperZoop.run()
# Out:
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=1 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=2 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=3 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=4 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=5 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=6 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=7 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=8 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=9 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=10 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=11 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=12 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=13 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=14 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=15 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=16 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=17 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=18 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=19 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=20 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=21 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=22 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=23 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=24 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=25 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=26 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=27 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=28 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=29 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=30 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=31 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=32 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=33 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=34 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=35 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=36 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=37 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=38 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=39 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=40 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=41 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=42 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=43 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=44 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=45 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=46 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=47 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=48 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=49 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=50 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=51 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=52 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=53 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=54 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=55 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=56 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=57 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=58 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=59 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=60 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=61 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=62 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=63 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=64 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=65 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=66 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=67 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=68 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=69 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=70 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=71 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=72 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=73 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=74 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=75 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=76 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=77 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=78 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=79 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=80 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=81 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=82 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=83 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=84 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=85 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=86 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=87 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=88 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=89 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=90 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=91 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=92 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=93 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=94 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=95 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=96 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=97 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=98 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=99 | Status code: 200
# HTTP GET request to URL: https://www.zoopla.co.uk/for-sale/property/london/?identifier=london&q=London&search_source=for-sale&radius=0&pn=100 | Status code: 200
# Stored results to "zoopla.csv"
